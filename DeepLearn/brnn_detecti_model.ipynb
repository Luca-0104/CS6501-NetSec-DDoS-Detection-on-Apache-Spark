# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns; sns.set()

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, LSTM, Bidirectional
from tensorflow.keras.utils import plot_model, to_categorical

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import confusion_matrix

# %%
number_of_samples = 50000

# %%
data_attack = pd.read_csv('./dataset/dataset_attack.csv', nrows = number_of_samples)

# %%
data_normal = pd.read_csv('./dataset/dataset_normal.csv', nrows = number_of_samples)

# %%
data_normal.columns=[ 'frame.len', 'frame.protocols', 'ip.hdr_len',
       'ip.len', 'ip.flags.rb', 'ip.flags.df', 'p.flags.mf', 'ip.frag_offset',
       'ip.ttl', 'ip.proto', 'ip.src', 'ip.dst', 'tcp.srcport', 'tcp.dstport',
       'tcp.len', 'tcp.ack', 'tcp.flags.res', 'tcp.flags.ns', 'tcp.flags.cwr',
       'tcp.flags.ecn', 'tcp.flags.urg', 'tcp.flags.ack', 'tcp.flags.push',
       'tcp.flags.reset', 'tcp.flags.syn', 'tcp.flags.fin', 'tcp.window_size',
       'tcp.time_delta','class']
data_attack.columns=[ 'frame.len', 'frame.protocols', 'ip.hdr_len',
       'ip.len', 'ip.flags.rb', 'ip.flags.df', 'p.flags.mf', 'ip.frag_offset',
       'ip.ttl', 'ip.proto', 'ip.src', 'ip.dst', 'tcp.srcport', 'tcp.dstport',
       'tcp.len', 'tcp.ack', 'tcp.flags.res', 'tcp.flags.ns', 'tcp.flags.cwr',
       'tcp.flags.ecn', 'tcp.flags.urg', 'tcp.flags.ack', 'tcp.flags.push',
       'tcp.flags.reset', 'tcp.flags.syn', 'tcp.flags.fin', 'tcp.window_size',
       'tcp.time_delta','class']

# %%
data_normal=data_normal.drop(['ip.src', 'ip.dst','frame.protocols'],axis=1)
data_attack=data_attack.drop(['ip.src', 'ip.dst','frame.protocols'],axis=1)

# %%
features=[ 'frame.len', 'ip.hdr_len',
       'ip.len', 'ip.flags.rb', 'ip.flags.df', 'p.flags.mf', 'ip.frag_offset',
       'ip.ttl', 'ip.proto', 'tcp.srcport', 'tcp.dstport',
       'tcp.len', 'tcp.ack', 'tcp.flags.res', 'tcp.flags.ns', 'tcp.flags.cwr',
       'tcp.flags.ecn', 'tcp.flags.urg', 'tcp.flags.ack', 'tcp.flags.push',
       'tcp.flags.reset', 'tcp.flags.syn', 'tcp.flags.fin', 'tcp.window_size',
       'tcp.time_delta']

# %%
X_normal= data_normal[features].values
X_attack= data_attack[features].values
Y_normal= data_normal['class']
Y_attack= data_attack['class']
X=np.concatenate((X_normal,X_attack))
Y=np.concatenate((Y_normal,Y_attack))

# %% [markdown]
# # Standardise the data

# %%
scalar = StandardScaler(copy=True, with_mean=True, with_std=True)
scalar.fit(X)
X = scalar.transform(X)

# %% [markdown]
# # the class field, replace value 'attack' with 0 and 'normal' with 1

# %%
for i in range(0,len(Y)):
  if Y[i] =="attack":
    Y[i]=0
  else:
    Y[i]=1

# %%
features = len(X[0])
samples = X.shape[0]
train_len = 25
input_len = samples - train_len
I = np.zeros((samples - train_len, train_len, features))

for i in range(input_len):
    temp = np.zeros((train_len, features))
    for j in range(i, i + train_len - 1):
        temp[j-i] = X[j]
    I[i] = temp

# %%
X.shape
# Out:
# (100000, 25)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(I, Y[25:100000], test_size = 0.2)

# %%
def create_baseline():
    model = Sequential()
    
    model.add(Bidirectional(LSTM(64, activation='tanh', kernel_regularizer='l2')))
    model.add(Dense(128, activation = 'relu', kernel_regularizer='l2'))
    model.add(Dense(1, activation = 'sigmoid', kernel_regularizer='l2'))
    
    model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    
    return model

# %%
model = create_baseline()

# %%
X_train = X_train.astype('float32')
Y_train = Y_train.astype('float32')
X_test = X_test.astype('float32')
Y_test = Y_test.astype('float32')
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# Y_train = scaler.fit_transform(Y_train)

# %%
history = model.fit(X_train, Y_train, epochs = 40,validation_split=0.2, verbose = 1)
# Out:
# Epoch 1/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - accuracy: 0.9159 - loss: 0.5267 - val_accuracy: 0.9515 - val_loss: 0.1961
# Epoch 2/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9530 - loss: 0.1852 - val_accuracy: 0.9556 - val_loss: 0.1703
# Epoch 3/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9577 - loss: 0.1646 - val_accuracy: 0.9540 - val_loss: 0.1787
# Epoch 4/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9597 - loss: 0.1545 - val_accuracy: 0.9649 - val_loss: 0.1669
# Epoch 5/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9635 - loss: 0.1477 - val_accuracy: 0.9662 - val_loss: 0.1354
# Epoch 6/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9654 - loss: 0.1348 - val_accuracy: 0.9557 - val_loss: 0.1656
# Epoch 7/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9652 - loss: 0.1356 - val_accuracy: 0.9688 - val_loss: 0.1237
# Epoch 8/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9670 - loss: 0.1308 - val_accuracy: 0.9627 - val_loss: 0.1497
# Epoch 9/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9663 - loss: 0.1343 - val_accuracy: 0.9689 - val_loss: 0.1187
# Epoch 10/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9679 - loss: 0.1283 - val_accuracy: 0.9727 - val_loss: 0.1343
# Epoch 11/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9671 - loss: 0.1269 - val_accuracy: 0.9700 - val_loss: 0.1297
# Epoch 12/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9693 - loss: 0.1195 - val_accuracy: 0.9721 - val_loss: 0.1350
# Epoch 13/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9704 - loss: 0.1176 - val_accuracy: 0.9709 - val_loss: 0.1264
# Epoch 14/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9699 - loss: 0.1233 - val_accuracy: 0.9701 - val_loss: 0.1207
# Epoch 15/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9695 - loss: 0.1194 - val_accuracy: 0.9724 - val_loss: 0.1123
# Epoch 16/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9705 - loss: 0.1166 - val_accuracy: 0.9735 - val_loss: 0.1049
# Epoch 17/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9711 - loss: 0.1158 - val_accuracy: 0.9742 - val_loss: 0.1136
# Epoch 18/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9707 - loss: 0.1172 - val_accuracy: 0.9504 - val_loss: 0.2056
# Epoch 19/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9703 - loss: 0.1239 - val_accuracy: 0.9646 - val_loss: 0.1522
# Epoch 20/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9704 - loss: 0.1170 - val_accuracy: 0.9736 - val_loss: 0.1101
# Epoch 21/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9717 - loss: 0.1155 - val_accuracy: 0.9740 - val_loss: 0.1125
# Epoch 22/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9725 - loss: 0.1131 - val_accuracy: 0.9721 - val_loss: 0.1139
# Epoch 23/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9717 - loss: 0.1127 - val_accuracy: 0.9731 - val_loss: 0.1098
# Epoch 24/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9714 - loss: 0.1148 - val_accuracy: 0.9647 - val_loss: 0.1350
# Epoch 25/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9725 - loss: 0.1122 - val_accuracy: 0.9740 - val_loss: 0.1071
# Epoch 26/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9722 - loss: 0.1129 - val_accuracy: 0.9743 - val_loss: 0.1049
# Epoch 27/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9713 - loss: 0.1125 - val_accuracy: 0.9759 - val_loss: 0.1132
# Epoch 28/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9717 - loss: 0.1155 - val_accuracy: 0.9719 - val_loss: 0.1059
# Epoch 29/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9737 - loss: 0.1080 - val_accuracy: 0.9762 - val_loss: 0.1059
# Epoch 30/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9744 - loss: 0.1071 - val_accuracy: 0.9701 - val_loss: 0.1169
# Epoch 31/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9730 - loss: 0.1093 - val_accuracy: 0.9724 - val_loss: 0.1109
# Epoch 32/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9739 - loss: 0.1078 - val_accuracy: 0.9736 - val_loss: 0.1054
# Epoch 33/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9736 - loss: 0.1097 - val_accuracy: 0.9768 - val_loss: 0.1083
# Epoch 34/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9721 - loss: 0.1104 - val_accuracy: 0.9797 - val_loss: 0.0964
# Epoch 35/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9758 - loss: 0.1032 - val_accuracy: 0.9756 - val_loss: 0.1071
# Epoch 36/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9767 - loss: 0.1015 - val_accuracy: 0.9653 - val_loss: 0.1505
# Epoch 37/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9727 - loss: 0.1148 - val_accuracy: 0.9756 - val_loss: 0.1028
# Epoch 38/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9757 - loss: 0.1018 - val_accuracy: 0.9787 - val_loss: 0.1045
# Epoch 39/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9760 - loss: 0.1017 - val_accuracy: 0.9806 - val_loss: 0.0911
# Epoch 40/40
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9765 - loss: 0.1006 - val_accuracy: 0.9792 - val_loss: 0.1022

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])       
plt.plot(history.history['val_accuracy']) 
plt.title('BRNN Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='lower right')
plt.savefig('BRNN Model Accuracy.png')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('BRNN Model  Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('BRNN Model Loss.png')
plt.show()

# %%
predict = model.predict(X_test, verbose=1)
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %%
tp = 0
tn = 0
fp = 0
fn = 0
predictn = predict.flatten().round()
predictn = predictn.tolist()
Y_testn = Y_test.tolist()
for i in range(len(Y_testn)):
  if predictn[i]==1 and Y_testn[i]==1:
    tp+=1
  elif predictn[i]==0 and Y_testn[i]==0:
    tn+=1
  elif predictn[i]==0 and Y_testn[i]==1:
    fp+=1
  elif predictn[i]==1 and Y_testn[i]==0:
    fn+=1

# %%
to_heat_map =[[tn,fp],[fn,tp]]
to_heat_map = pd.DataFrame(to_heat_map, index = ["Attack","Normal"],columns = ["Attack","Normal"])
ax = sns.heatmap(to_heat_map,annot=True, fmt="d")
